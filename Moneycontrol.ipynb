# %% [markdown]
# Money Control Webscrapping every 5 min

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.moneycontrol.com/news/business/markets/"
headers = {
    "User-Agent": "Mozilla/5.0"
}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")
headlines = soup.find_all("h2")
for news in headlines:
    print(news.text.strip())
# Out:
# Gujarat Kidney and Super Speciality IPO GMP rises as subscription begins on Monday; check key details
# India sees highest foreign inflows in eight months as global risk appetite improves: Elara Capital
# ITI shares rise 13% on plans to monetise land parcels to raise nearly Rs 3,500 crore
# KSH International IPO allotment: How to check status on registrar, BSE and NSE; check latest GMP
# Technical View: Nifty needs decisive rise above 26,000 for strong momentum; VIX extends decline to fourth week, hits new record low
# Waaree Energies shares rise 6% on F&O inclusion, $30-mn investment in United Solar
# Voltas shares fall up to 3% as brokerages anticipate subdued demand amid multiple headwinds
# Bubbles and boring bets: What’s coming for tech stocks in 2026
# Taking Stock: Market snaps four-day fall; Nifty above 25,900, broader indices shine
# Banking system cash squeeze sends overnight rates above RBI’s repo rate
# Coca-Cola India FY25 profit up 46.3% to Rs 615 crore, revenue at Rs 5,042.56 crore
# Tata Power raises Rs 2,000 crore via issuance of NCDs
# IT shares extend gains for 3rd day, but Jefferies sees downside risk after Accenture's muted guidance
# Nifty Knocks At 26,000 As 4-Day Losing Streak Halts; Shriram Fin-MUFG Deal Sealed| Closing Bell Live
# Ather Energy shares gain 4% as board approves foray into insurance
# AMS shares gain after subsidiary secures defence explosive license
# High-net-worth Indians shift strategy post-Covid, drive LRS investment four-fold higher
# Vodafone Idea shares jump 6% as arm raises Rs 3,300 crore via NCDs
# Prediction markets and the casino mentality of 2025
# Sensex declines 250 pts from day's high, Nifty below 25,950: 3 key reasons behind market paring gains
# Shriram Finance shares rise 4% to hit record high after Rs 39,600-crore MUFG deal
# Sebi’s high value debt entity tweak may have limited impact on lower-rated bonds
# ICICI Prudential AMC delivers second-best returns among over Rs 10,000-crore IPOs of 2025
# “IPO journey changes nothing”: S Naren focuses on ICICI Pru AMC’s investor-first playbook
# Does Accenture’s good report mean a steady Q3 for Indian IT players?
# Watch
# You got 30 Day’s Trial of
